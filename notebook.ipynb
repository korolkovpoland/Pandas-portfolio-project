# %%
import pandas as pd
from main import *
# Out:
# 25
# c:\Users\Zeus\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\Zeus\Desktop\Завдання\src\cleaning.py:70: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   clean_col['Culer'] = clean_col['Culer'].ffill()
# Скрипт загружен и работает...!

# %%
global_table
# Out:
#                 DateTime  Закупівля, кВт.г  Фактичні обсяги споживання, кВт.г  \
# 0    2025-01-01 01:00:00          130695.2                        136593.0358
# 1    2025-01-01 02:00:00          126162.6                        133596.8034
# 2    2025-01-01 03:00:00          123128.4                        129209.0204
# 3    2025-01-01 04:00:00          122023.8                        125728.4098
# 4    2025-01-01 05:00:00          120268.6                        123759.9052
# ...                  ...               ...                                ...
# 8681 2025-06-30 20:00:00          120313.0                        120052.0000
# 8682 2025-06-30 21:00:00          118828.0                        118996.0000
# 8683 2025-06-30 22:00:00          117940.0                        118473.0000
# 8684 2025-06-30 23:00:00          112300.0                        110469.0000
# 8685 2025-06-30 00:00:00           95890.0                         93345.0000
#
# ...
